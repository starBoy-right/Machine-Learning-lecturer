# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/a/Programming/Machine-Learning-Folder/First-Meet/data/day.csv')

# %%
data_training= int(0.8 * len(df))
data_testing = int(0.2 * len(df))

# %%
df_training = df[:data_training] 
df_training.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# data validation, 10 persen dari traning
data_validation = int(0.1 * len(df_training))
df_validation = df_training[:data_validation]
df_validation.shape
# Out:
# (58, 16)

# %%
# data testing, 20 persen dari dataset
data_testing = df[data_training:]
data_testing.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 584      585  2012-08-07       3   1     8        0        2           1
# 585      586  2012-08-08       3   1     8        0        3           1
# 586      587  2012-08-09       3   1     8        0        4           1
# 587      588  2012-08-10       3   1     8        0        5           1
# 588      589  2012-08-11       3   1     8        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 584           2  0.735833  0.697621  0.703750   0.116908    1278        5995
# 585           2  0.750000  0.707717  0.672917   0.110700    1263        6271
# 586           1  0.755833  0.699508  0.620417   0.156100    1196        6090
# 587           2  0.715833  0.667942  0.715833   0.238813    1065        4721
# 588           2  0.692500  0.638267  0.732917   0.206479    2247        4052
#
#       cnt
# 584  7273
# 585  7534
# 586  7286
# 587  5786
# ...

# %% [markdown]
# ### **Menggunakan Library Scikit-learn**

# %%
from sklearn.model_selection import train_test_split

# %%
# membagi 80% data menjadi data training dan 20 persen menjadi data testing
training_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# kemudian membagi 10 persen dari data training kedalam data validation
training_data, validation_data = train_test_split(training_data, test_size=0.1, random_state=42)

# %%
training_data.shape
# Out:
# (525, 16)

# %%
test_data.shape
# Out:
# (147, 16)

# %%
validation_data.shape
# Out:
# (59, 16)

# %%
training_data.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 657      658  2012-10-19       4   1    10        0        5           1
# 163      164  2011-06-13       2   0     6        0        1           1
# 305      306  2011-11-02       4   0    11        0        3           1
# 111      112  2011-04-22       2   0     4        0        5           1
# 538      539  2012-06-22       3   1     6        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 657           2  0.563333  0.537896  0.815000   0.134954     753        4671
# 163           1  0.635000  0.601654  0.494583   0.305350     863        4157
# 305           1  0.377500  0.390133  0.718750   0.082092     370        3816
# 111           2  0.336667  0.321954  0.729583   0.219521     177        1506
# 538           1  0.777500  0.724121  0.573750   0.182842     964        4859
#
#       cnt
# 657  5424
# 163  5020
# 305  4186
# 111  1683
# ...

# %%
validation_data.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 325      326  2011-11-22       4   0    11        0        2           1
# 410      411  2012-02-15       1   1     2        0        3           1
# 92        93  2011-04-03       2   0     4        0        0           0
# 47        48  2011-02-17       1   0     2        0        4           1
# 508      509  2012-05-23       2   1     5        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 325           3  0.416667  0.421696  0.962500   0.118792      69        1538
# 410           1  0.348333  0.351629  0.531250   0.181600     141        4028
# 92            1  0.378333  0.378767  0.480000   0.182213    1651        1598
# 47            1  0.435833  0.428658  0.505000   0.230104     259        2216
# 508           2  0.621667  0.584612  0.774583   0.102000     766        4494
#
#       cnt
# 325  1607
# 410  4169
# 92   3249
# 47   2475
# ...

# %%
test_data.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 703      704  2012-12-04       4   1    12        0        2           1
# 33        34  2011-02-03       1   0     2        0        4           1
# 300      301  2011-10-28       4   0    10        0        5           1
# 456      457  2012-04-01       2   1     4        0        0           0
# 633      634  2012-09-25       4   1     9        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 703           1  0.475833  0.469054  0.733750   0.174129     551        6055
# 33            1  0.186957  0.177878  0.437826   0.277752      61        1489
# 300           2  0.330833  0.318812  0.585833   0.229479     456        3291
# 456           2  0.425833  0.417287  0.676250   0.172267    2347        3694
# 633           1  0.550000  0.544179  0.570000   0.236321     845        6693
#
#       cnt
# 703  6606
# 33   1550
# 300  3747
# 456  6041
# ...
